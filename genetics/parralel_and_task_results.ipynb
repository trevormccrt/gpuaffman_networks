# %%
import cupy as cp
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import networkx as nx
import os
import pickle
import sys


sys.path.append(os.path.join(os.getenv("HOME"), "gpuaffman_networks/"))
import general_network_visualization, parralel_and_task_evolution, ragged_task_evolution, ragged_general_network
from genetics import analysis_util

# %%
data_dir = os.path.join(os.getenv("HOME"), "boolean_network_data/parralel_and_evolution_results/2023-02-15-13-18-54")
best_error = np.load(os.path.join(data_dir, "best_errors.npy"))
with open(os.path.join(data_dir,"best_populations.pk"), "rb") as f:
    populations = pickle.load(f)

# %%
N = populations[0][0].shape[0]
input_state = cp.asnumpy(parralel_and_task_evolution.make_pnand_input_state(N))
batched_input_state = np.broadcast_to(np.expand_dims(np.expand_dims(input_state, 1), 1), (input_state.shape[0], len(populations), 1, N)).astype(np.bool_)
best_functions = np.expand_dims(np.stack([x[0] for x in populations], axis=0), 1).astype(np.bool_)
best_conn = np.expand_dims(np.stack([x[1] for x in populations], axis=0), 1).astype(np.int16)
best_used_conn = np.expand_dims(np.stack([x[2] for x in populations], axis=0), 1).astype(np.bool_)

# %%
best_functions, best_conn, best_used_conn, sorted_perfs =  analysis_util.sort_by_performance(batched_input_state, best_functions, best_conn, best_used_conn, parralel_and_task_evolution.evaluate_pnand_task)

# %%
graphs = [general_network_visualization.influence_graph_from_ragged_spec(x[0], x[1], x[2]) for x in populations]

# %%
best_to_plot = 2
to_plot = graphs[:best_to_plot]
fig, axs = plt.subplots(ncols=len(to_plot), figsize=(10,5))
node_colors = ["C0"] * N
node_colors[0] = "C1"
node_colors[1] = "C1"
node_colors[2] = "C1"
node_colors[3] = "C1"
node_colors[4] = "C2"
node_colors[5] = "C2"


for g, ax, err in zip(graphs, axs, sorted_perfs[:best_to_plot]):
    pos = nx.spring_layout(g, iterations=10000)
    general_network_visualization.plot_network_directed(g, pos, ax, node_colors)
    ax.set_title("{:.2E}".format(err))
fig.tight_layout()

# %%
influence = analysis_util.compute_influence(best_functions[:2, 0, ...])

# %%
example_trajs, example_noise = analysis_util.run_dynamics_forward_save_state(batched_input_state, best_functions, best_conn, best_used_conn, 10, 0)
example_trajs = np.squeeze(example_trajs, -2)
example_noise = np.squeeze(example_noise, -2)

# %%
to_plot = [0, 3, -2, -1]
fig, axs = plt.subplots(nrows=len(to_plot), ncols=best_to_plot, figsize=(5, 5))
for i in range(best_to_plot):
    for j, k in enumerate(to_plot):
        axs[j, i].pcolor(example_trajs[:, k, i, :], cmap="Greys", linewidth=0.3, edgecolors="blue")
fig.tight_layout()

# %%
physical_error_rates = np.linspace(start=0, stop=0.01, num=20)
logical_error_rates = analysis_util.generate_ft_curve(physical_error_rates, batched_input_state, best_functions, best_conn, best_used_conn, parralel_and_task_evolution.evaluate_pnand_task, n_traj=5000)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[22], line 2
#       1 physical_error_rates = np.linspace(start=0, stop=0.01, num=20)
# ----> 2 logical_error_rates = analysis_util.generate_ft_curve(physical_error_rates, batched_input_state, best_functions, best_conn, best_used_conn, parralel_and_task_evolution.evaluate_pnand_task, n_traj=10000)
#
# File ~/gpuaffman_networks/genetics/analysis_util.py:29, in generate_ft_curve(physical_error_rates, input_state, functions, connectivity, used_connectivity, f_eval, n_traj, n_timesteps)
#      27 logical_error_rates = []
#      28 for error_rate in physical_error_rates:
# ---> 29     logical_error_rates.append(np.squeeze(ragged_task_evolution.evaluate_populations(input_state, n_traj, functions, connectivity, used_connectivity, n_timesteps, error_rate, f_eval), -1))
#      30 return np.array(logical_error_rates)
#
# File ~/gpuaffman_networks/genetics/ragged_task_evolution.py:73, in evaluate_populations(input_states, n_trajectories, functions, connectivity, used_connectivity, n_timesteps, noise_prob, f_eval)
#      70 def evaluate_populations(input_states, n_trajectories, functions, connectivity,
#      71                          used_connectivity, n_timesteps, noise_prob, f_eval):
#      72     return f_eval(
# ---> 73         run_dynamics_forward(np.broadcast_to(np.expand_dims(input_states, 0), (n_trajectories, *input_states.shape)),
#      74                              functions, connectivity, used_connectivity, n_timesteps, noise_prob))
#
# File ~/gpuaffman_networks/genetics/ragged_task_evolution.py:65, in run_dynamics_forward(input_state, functions, connections, used_connections, n_timesteps, p_noise)
#      63 current_state = input_state
#      64 for _ in range(n_timesteps):
# ---> 65     current_state = np.bitwise_xor(ragged_general_network.ragged_k_state_update(current_state, functions, connections, used_connections),
#      66                                    xp.random.binomial(1, p_noise, current_state.shape).astype(np.bool_))
#      67 return ragged_general_network.ragged_k_state_update(current_state, functions, connections, used_connections)
#
# File ~/gpuaffman_networks/ragged_general_network.py:14, in ragged_k_state_update(states, functions, connections, used_connections)
#      13 def ragged_k_state_update(states, functions, connections, used_connections):
# ---> 14     return apply_ragged_k_binary_function(general_network.get_update_inputs(states, connections),
#      15                                           functions, used_connections)
#
# File ~/gpuaffman_networks/general_network.py:10, in get_update_inputs(states, connections)
#       8 def get_update_inputs(states, connections):
#       9     connections = np.broadcast_to(connections, (*states.shape, connections.shape[-1]))
# ---> 10     return np.take_along_axis(np.expand_dims(states, -1), connections, -2)
#
# File <__array_function__ internals>:180, in take_along_axis(*args, **kwargs)
#
# File ~/brainvenv/lib/python3.8/site-packages/numpy/lib/shape_base.py:170, in take_along_axis(arr, indices, axis)
#     167     arr_shape = arr.shape
#     169 # use the fancy index
# --> 170 return arr[_make_along_axis_idx(arr_shape, indices, axis)]
#
# KeyboardInterrupt:

# %%
fig, axs = plt.subplots()
logical_error_rates = np.array(logical_error_rates)
for j in range(best_to_plot):
    axs.plot(physical_error_rates, logical_error_rates[:, j], label="{}".format(j))
axs.set_xlabel("Physical Error Rate")
axs.set_ylabel("Logical Error Rate")
axs.legend()
